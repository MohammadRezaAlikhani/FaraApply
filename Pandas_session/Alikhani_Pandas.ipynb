# %% [markdown]
# برای کار با داده های جدولی

# %%
# import
import pandas as pd

# %%
# import data
df = pd.read_csv("Dolar.csv")

# %%
df.dtypes
# Out:
# J-Date     object
# Date       object
# Weekday    object
# Open        int64
# High        int64
# Low         int64
# Close       int64
# dtype: object

# %%
df.head()
#df.tail(20)
# Out:
#        J-Date        Date    Weekday   Open   High    Low  Close
# 0  1390-09-05  2011-11-26   Saturday  13700  13700  13700  13700
# 1  1390-09-06  2011-11-27     Sunday  13440  13440  13440  13440
# 2  1390-09-07  2011-11-28     Monday  13350  13350  13350  13350
# 3  1390-09-08  2011-11-29    Tuesday  13400  13400  13400  13400
# 4  1390-09-09  2011-11-30  Wednesday  13500  13500  13500  13500

# %%
df.corr(method='pearson')
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20004\1928163937.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#            Open      High       Low     Close
# Open   1.000000  0.999868  0.999606  0.999784
# High   0.999868  1.000000  0.999431  0.999827
# Low    0.999606  0.999431  1.000000  0.999606
# Close  0.999784  0.999827  0.999606  1.000000

# %%
# table = dataframe
# column = series
df['J-Date']
# Out:
# 0       1390-09-05
# 1       1390-09-06
# 2       1390-09-07
# 3       1390-09-08
# 4       1390-09-09
#            ...
# 3764    1402-10-12
# 3765    1402-10-13
# 3766    1402-10-14
# 3767    1402-10-16
# 3768    1402-10-17
# Name: J-Date, Length: 3769, dtype: object

# %%
print(f"type column: {type(a)}")
print(f"type table (dataframe): {type(df)}")
# Out:
# type column: <class 'pandas.core.series.Series'>
# type table (dataframe): <class 'pandas.core.frame.DataFrame'>

# %%
# Get information from my dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3769 entries, 0 to 3768
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   J-Date   3769 non-null   object
#  1   Date     3769 non-null   object
#  2   Weekday  3769 non-null   object
#  3   Open     3769 non-null   int64
#  4   High     3769 non-null   int64
#  5   Low      3769 non-null   int64
#  6   Close    3769 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 206.2+ KB

# %%
df.describe(include='all')
# Out:
#             J-Date        Date   Weekday           Open           High  \
# count         3769        3769      3769    3769.000000    3769.000000
# unique        3742        3742         7            NaN            NaN
# top     1402-07-22  2023-10-14  Saturday            NaN            NaN
# freq             3           3       590            NaN            NaN
# mean           NaN         NaN       NaN  137744.292916  138571.740515
# std            NaN         NaN       NaN  143090.689799  143853.346173
# min            NaN         NaN       NaN   13350.000000   13350.000000
# 25%            NaN         NaN       NaN   33660.000000   33890.000000
# 50%            NaN         NaN       NaN   45130.000000   45650.000000
# 75%            NaN         NaN       NaN  238970.000000  239540.000000
# max            NaN         NaN       NaN  548860.000000  555600.000000
#
#                   Low          Close
# count     3769.000000    3769.000000
# unique            NaN            NaN
# ...

# %% [markdown]
# Data selection

# %%
"""
df_name[(filter statement) & () & ()]
"""

df[(df["J-Date"]>="1400-10-18") & (df["Weekday"]=="Wednesday")]
# Out:
#           J-Date        Date    Weekday    Open    High     Low   Close
# 3211  1400-10-22  2022-01-12  Wednesday  277400  277400  277400  277400
# 3218  1400-10-29  2022-01-19  Wednesday  274650  275590  274550  275250
# 3225  1400-11-06  2022-01-26  Wednesday  277240  278100  276860  277710
# 3232  1400-11-13  2022-02-02  Wednesday  273050  274000  271960  272650
# 3239  1400-11-20  2022-02-09  Wednesday  262390  262400  262150  262270
# ...          ...         ...        ...     ...     ...     ...     ...
# 3737  1402-09-08  2023-11-29  Wednesday  503310  521000  501400  505190
# 3743  1402-09-15  2023-12-06  Wednesday  504940  504950  502860  504310
# 3749  1402-09-22  2023-12-13  Wednesday  503510  504150  502950  503850
# 3759  1402-10-06  2023-12-27  Wednesday  500100  502650  499760  502520
# 3765  1402-10-13  2024-01-03  Wednesday  505470  508200  505160  507500
#
# [85 rows x 7 columns]

# %%
df = df[(df["J-Date"]>="1400-10-18") & (df["Weekday"]=="Wednesday")]

# %%
# create a new column
df["sotoone_jadid"] = df["Close"] + df["Open"]

# %%
def plusone(x):
    """
    get x and return x+1
    """
    return x+1

# %%
# Data manipulation

# df["Close"] = df['Close'] +1
# df['Close'].apply(lambda x: x+1)
df['Close'].apply(plusone)
# Out:
# 3211    277401.0
# 3218    275251.0
# 3225    277711.0
# 3232    272651.0
# 3239    262271.0
#           ...
# 3737    505191.0
# 3743    504311.0
# 3749    503851.0
# 3759    502521.0
# 3765    507501.0
# Name: Close, Length: 85, dtype: float64

# %%
# delete a comumn
df.drop(columns=['Low'], inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#         J-Date        Date    Weekday    Open    High     Close  sotoone_jadid
# 0   1400-10-22  2022-01-12  Wednesday  277400  277400  277400.0         554800
# 1   1400-10-29  2022-01-19  Wednesday  274650  275590  275250.0         549900
# 2   1400-11-06  2022-01-26  Wednesday  277240  278100  277710.0         554950
# 3   1400-11-13  2022-02-02  Wednesday  273050  274000  272650.0         545700
# 4   1400-11-20  2022-02-09  Wednesday  262390  262400  262270.0         524660
# ..         ...         ...        ...     ...     ...       ...            ...
# 80  1402-09-08  2023-11-29  Wednesday  503310  521000  505190.0        1008500
# 81  1402-09-15  2023-12-06  Wednesday  504940  504950  504310.0        1009250
# 82  1402-09-22  2023-12-13  Wednesday  503510  504150  503850.0        1007360
# 83  1402-10-06  2023-12-27  Wednesday  500100  502650  502520.0        1002620
# 84  1402-10-13  2024-01-03  Wednesday  505470  508200  507500.0        1012970
#
# [85 rows x 7 columns]

# %% [markdown]
# Indexing in `Python`
#
# first = row
#
# second = column
#
# Indexing in `Pandas`
#
# first = column
#
# second = row

# %%
df.iloc[2,3]
# Out:
# 277240

# %%
df.loc[2,'Open']
# Out:
# 277240

# %% [markdown]
# `Pandas indexing`
#
# first = column name
#
# second = row

# %%
df['Open'][2] = 280000
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20004\2683393275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Open'][2] = 280000

# %%
df.iloc[0,2] = "Sunday"

# %%
df.loc[0,'sotoone_jadid'] = 0

# %%
df
# Out:
#         J-Date        Date    Weekday    Open    High     Close  sotoone_jadid
# 0   1400-10-22  2022-01-12     Sunday  277400  277400  277400.0              0
# 1   1400-10-29  2022-01-19  Wednesday  274650  275590  275250.0         549900
# 2   1400-11-06  2022-01-26  Wednesday  980980  278100  277710.0         554950
# 3   1400-11-13  2022-02-02  Wednesday  273050  274000  272650.0         545700
# 4   1400-11-20  2022-02-09  Wednesday  262390  262400  262270.0         524660
# ..         ...         ...        ...     ...     ...       ...            ...
# 80  1402-09-08  2023-11-29  Wednesday  503310  521000  505190.0        1008500
# 81  1402-09-15  2023-12-06  Wednesday  504940  504950  504310.0        1009250
# 82  1402-09-22  2023-12-13  Wednesday  503510  504150  503850.0        1007360
# 83  1402-10-06  2023-12-27  Wednesday  500100  502650  502520.0        1002620
# 84  1402-10-13  2024-01-03  Wednesday  505470  508200  507500.0        1012970
#
# [85 rows x 7 columns]

# %%
df.to_excel("test.xlsx",sheet_name="sheet1", index=False)

# %%
df.to_csv("test2csv.csv", index=False)

# %%
df.columns
# Out:
# Index(['J-Date', 'Date', 'Weekday', 'Open', 'High', 'Close', 'sotoone_jadid'], dtype='object')

# %%
df.rename(columns={"sotoone_jadid":"Jadid"})
# Out:
#         J-Date        Date    Weekday    Open    High     Close    Jadid
# 0   1400-10-22  2022-01-12     Sunday  277400  277400  277400.0        0
# 1   1400-10-29  2022-01-19  Wednesday  274650  275590  275250.0   549900
# 2   1400-11-06  2022-01-26  Wednesday  980980  278100  277710.0   554950
# 3   1400-11-13  2022-02-02  Wednesday  273050  274000  272650.0   545700
# 4   1400-11-20  2022-02-09  Wednesday  262390  262400  262270.0   524660
# ..         ...         ...        ...     ...     ...       ...      ...
# 80  1402-09-08  2023-11-29  Wednesday  503310  521000  505190.0  1008500
# 81  1402-09-15  2023-12-06  Wednesday  504940  504950  504310.0  1009250
# 82  1402-09-22  2023-12-13  Wednesday  503510  504150  503850.0  1007360
# 83  1402-10-06  2023-12-27  Wednesday  500100  502650  502520.0  1002620
# 84  1402-10-13  2024-01-03  Wednesday  505470  508200  507500.0  1012970
#
# [85 rows x 7 columns]

# %%
df[['Open','High','Close']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Dataframe 2

# %%
df = pd.read_csv("ECONOMIC_Cn NEW.csv")
df.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name     Series Code  \
# 0                                  Population, total     SP.POP.TOTL
# 1                       Population growth (annual %)     SP.POP.GROW
# 2                              Surface area (sq. km)  AG.SRF.TOTL.K2
# 3  Poverty headcount ratio at national poverty li...     SI.POV.NAHC
# 4                    GNI, Atlas method (current US$)  NY.GNP.ATLS.CD
#
#         2000 [YR2000]        2001 [YR2001]        2002 [YR2002]  \
# 0            19542982             19688632             21000256
# 1  14.438.030.241.194  742.516.834.396.313  644.932.147.797.304
# 2              652860               652860               652860
# 3                  ..                   ..                   ..
# ...

# %%
df['Country Code'].unique()
# Out:
# array(['AFG', 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'ATG', 'ARG', 'ARM',
#        'ABW', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR', 'BGD', 'BRB', 'BLR',
#        'BEL', 'BLZ', 'BEN', 'BMU', 'BTN', 'BOL', 'BIH', 'BWA', 'BRA',
#        'VGB', 'BRN', 'BGR', 'BFA', 'BDI', 'CPV', 'KHM', 'CMR', 'CAN',
#        'CYM', 'CAF', 'TCD', 'CHI', 'CHL', 'CHN', 'COL', 'COM', 'COD',
#        'COG', 'CRI', 'CIV', 'HRV', 'CUB', 'CUW', 'CYP', 'CZE', 'DNK',
#        'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'SLV', 'GNQ', 'ERI', 'EST',
#        'ETH', 'FRO', 'FJI', 'FIN', 'FRA', 'PYF', 'GAB', 'GMB', 'GEO',
#        'DEU', 'GHA', 'GIB', 'GRC', 'GRL', 'GRD', 'GUM', 'GTM', 'GIN',
#        'GNB', 'GUY', 'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN',
#        'IRN', 'IRQ', 'IRL', 'IMN', 'ISR', 'ITA', 'JAM', 'JPN', 'JOR',
#        'KAZ', 'KEN', 'KIR', 'PRK', 'KOR', 'XKX', 'KWT', 'KGZ', 'LAO',
#        'LVA', 'LBN', 'LSO', 'LBR', 'LBY', 'LIE', 'LTU', 'LUX', 'MAC',
# ...

# %%
df.groupby(by="Country Code").count()
# Out:
#                                                     Country Name  Series Name  \
# Country Code
# ABW                                                           48           48
# AFG                                                           48           48
# AGO                                                           48           48
# ALB                                                           48           48
# AND                                                           48           48
# ...                                                          ...          ...
# game reserves                                                  1            1
# independent of the source of income of the send...             1            1
# infant                                                         1            1
# please refer to the International Comparison Pr...             2            1
# seasonal                                                       1            1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10502 entries, 0 to 10501
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   10491 non-null  object
#  1   Country Code   10475 non-null  object
#  2   Series Name    10473 non-null  object
#  3   Series Code    10445 non-null  object
#  4   2000 [YR2000]  10486 non-null  object
#  5   2001 [YR2001]  10484 non-null  object
#  6   2002 [YR2002]  10483 non-null  object
#  7   2003 [YR2003]  10437 non-null  object
#  8   2004 [YR2004]  10439 non-null  object
#  9   2005 [YR2005]  10480 non-null  object
#  10  2006 [YR2006]  10437 non-null  object
#  11  2007 [YR2007]  10477 non-null  object
#  12  2008 [YR2008]  10474 non-null  object
#  13  2009 [YR2009]  10464 non-null  object
#  14  2010 [YR2010]  10464 non-null  object
#  15  2011 [YR2011]  10452 non-null  object
#  16  2012 [YR2012]  10436 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Country Name     0
# Country Code     0
# Series Name      0
# Series Code      0
# 2000 [YR2000]    0
# 2001 [YR2001]    0
# 2002 [YR2002]    0
# 2003 [YR2003]    0
# 2004 [YR2004]    0
# 2005 [YR2005]    0
# 2006 [YR2006]    0
# 2007 [YR2007]    0
# 2008 [YR2008]    0
# 2009 [YR2009]    0
# 2010 [YR2010]    0
# 2011 [YR2011]    0
# 2012 [YR2012]    0
# 2013 [YR2013]    0
# 2014 [YR2014]    0
# 2015 [YR2015]    0
# dtype: int64

# %%
df.dropna(axis=0,how='any', inplace=True)

# %%
df['Country Name'].drop_duplicates(keep='first')
# Out:
# 0            Afghanistan
# 48               Albania
# 96               Algeria
# 144       American Samoa
# 192              Andorra
#               ...
# 10272        Yemen, Rep.
# 10320             Zambia
# 10368           Zimbabwe
# 10421               Code
# 10490    9 Armament 891"
# Name: Country Name, Length: 219, dtype: object
